# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_excel('/Users/petrick/Desktop/Original_Dataset.xlsx',sheet_name='Sheet1')

# %%
sheet= pd.ExcelFile('/Users/petrick/Desktop/Original_Dataset.xlsx')

# %%
sheet.sheet_names
# Out:
# ['DPW', 'Elm', 'Esm', 'HB1', 'KS3', 'LA1', 'LA2', 'NC1', 'NC2', 'NC4', 'xDL']

# %%
df_list= [pd.read_excel('/Users/petrick/Desktop/Original_Dataset.xlsx',sheet_name=sheet) for sheet in sheet.sheet_names]
df_final= pd.concat(df_list)

# %%
df_final.shape
# Out:
# (25696, 26)

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# Date             1464.0  2.014573e+07  11235.122535  2.013010e+07
# NEE              1464.0 -9.081671e+02   2874.675937 -9.999000e+03
# SW_IN            1464.0  1.994633e+02     66.182491  2.079500e+01
# TA               1464.0  2.237911e+01      4.855949  4.311354e+00
# VPD              1464.0  5.920299e+00      2.522457  5.145833e-02
# P                1464.0  3.613858e+00      4.887357  0.000000e+00
# SWC              1464.0  1.324875e+01      2.279650  8.069700e+00
# WS               1464.0  6.465762e-01      0.265508  2.022083e-01
# TS               1464.0  2.415764e+01      4.222835  1.123700e+01
# WTD              1454.0 -1.501288e-01      0.267383 -8.581390e-01
# WTDdiff          1450.0 -2.522483e-05      0.020887 -1.402080e-01
# SIN(DOY)         1464.0  7.052912e-05      0.706625 -9.999907e-01
# COS(DOY)         1464.0  2.047764e-03      0.708068 -1.000000e+00
# ...

# %%
# df.head()
for column in df_final.columns:
    df_final[column] = df_final[column].replace(-9999.0, np.NaN)

# %%
df_final.head()
# Out:
#        Date  NEE       SW_IN         TA       VPD      P     SWC        WS  \
# 0  20130101  NaN  141.380937  17.531521  4.257604  0.000  11.072  0.589660
# 1  20130102  NaN  128.071396  18.890812  4.182708  0.000  10.953  0.508333
# 2  20130103  NaN  104.494854  19.734479  3.302667  0.358  10.843  0.407667
# 3  20130104  NaN   60.676063  16.325646  1.705688  1.238  10.883  0.794500
# 4  20130105  NaN  126.006979  17.840271  4.321708  0.000  10.985  0.665479
#
#        TS       WTD  ...  LAI_daily  LAI_month_max  FAPAR_daily  \
# 0  17.521 -0.245491  ...        NaN          1.367          NaN
# 1  18.175 -0.260731  ...        NaN          1.367          NaN
# 2  19.835 -0.239395  ...        NaN          1.367          NaN
# 3  19.675 -0.193675  ...        NaN          1.367          NaN
# 4  19.505 -0.251587  ...        NaN          1.367          NaN
#
#    FAPAR_month_max    NDVI  SIF_daily_8day  SIF_month  Unnamed: 23  \
# ...

# %%
df_final.isnull().sum()
# Out:
# Date                   0
# NEE                 7302
# SW_IN               2780
# TA                   667
# VPD                  873
# P                   1214
# SWC                 3870
# WS                  2576
# TS                  2556
# WTD                 3555
# WTDdiff             3618
# SIN(DOY)               0
# COS(DOY)               0
# PDSI                   0
# Month                  0
# Year                   0
# LAI_daily          22186
# LAI_month_max       6318
# FAPAR_daily        22186
# FAPAR_month_max     6318
# NDVI                1837
# SIF_daily_8day      1461
# SIF_month           1461
# Unnamed: 23            0
# Unnamed: 24         1461
# Unnamed: 25         1461
# dtype: int64

# %%
df_final.isnull().sum() / df_final.shape[0] * 100
# Out:
# Date                0.000000
# NEE                28.416874
# SW_IN              10.818804
# TA                  2.595735
# VPD                 3.397416
# P                   4.724471
# SWC                15.060710
# WS                 10.024907
# TS                  9.947073
# WTD                13.834838
# WTDdiff            14.080012
# SIN(DOY)            0.000000
# COS(DOY)            0.000000
# PDSI                0.000000
# Month               0.000000
# Year                0.000000
# LAI_daily          86.340286
# LAI_month_max      24.587484
# FAPAR_daily        86.340286
# FAPAR_month_max    24.587484
# NDVI                7.148973
# SIF_daily_8day      5.685710
# SIF_month           5.685710
# Unnamed: 23         0.000000
# Unnamed: 24         5.685710
# Unnamed: 25         5.685710
# dtype: float64

# %%
df_final['label']= df_final['NEE'].isnull()

# %%
df_final
# Out:
#           Date  NEE       SW_IN         TA        VPD       P     SWC  \
# 0     20130101  NaN  141.380937  17.531521   4.257604   0.000  11.072
# 1     20130102  NaN  128.071396  18.890812   4.182708   0.000  10.953
# 2     20130103  NaN  104.494854  19.734479   3.302667   0.358  10.843
# 3     20130104  NaN   60.676063  16.325646   1.705688   1.238  10.883
# 4     20130105  NaN  126.006979  17.840271   4.321708   0.000  10.985
# ...        ...  ...         ...        ...        ...     ...     ...
# 2001  20220625  NaN  309.871354  27.837000  12.764598   0.000     NaN
# 2002  20220626  NaN  304.912500  28.043937  11.878873   0.000     NaN
# 2003  20220627  NaN  187.964375  25.764000   6.328421  19.361     NaN
# 2004  20220628  NaN  194.089167  25.314521   6.976871   0.000     NaN
# 2005  20220629  NaN  173.742396  24.744854   4.720094   0.000     NaN
#
#             WS         TS       WTD  ...  LAI_month_max  FAPAR_daily  \
# ...

# %%
df_final.corr()
# Out:
#                      Date       NEE     SW_IN        TA       VPD         P  \
# Date             1.000000 -0.065567  0.050212 -0.001196  0.074787  0.004451
# NEE             -0.065567  1.000000 -0.365836 -0.025328 -0.218935  0.153218
# SW_IN            0.050212 -0.365836  1.000000  0.437325  0.445377 -0.259254
# TA              -0.001196 -0.025328  0.437325  1.000000  0.211593  0.091948
# VPD              0.074787 -0.218935  0.445377  0.211593  1.000000 -0.129414
# P                0.004451  0.153218 -0.259254  0.091948 -0.129414  1.000000
# SWC              0.119158  0.062361 -0.036127  0.098360 -0.351538  0.006604
# WS              -0.063383  0.016235 -0.134903 -0.116134 -0.094388  0.057540
# TS              -0.012133  0.005233  0.404929  0.901252  0.051331  0.105616
# WTD             -0.320454  0.167205 -0.074979  0.189501 -0.302570  0.024691
# WTDdiff         -0.002719  0.076424 -0.188602  0.027289 -0.086593  0.341459
# ...

# %%
sns.heatmap(df_final.corr(), cbar=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>
